# %% [markdown]
# ## **Imports and Paths**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import geopandas as gpd
import pandas as pd

BASE_DIR= "/content/drive/MyDrive/Colab Notebooks/Kenya_Cholera_Climate_Risk_Model"

PRED_PATH = f"{BASE_DIR}/data/processed/kenya_cholera_predictions.csv"
GADM_PATH = f"{BASE_DIR}/data/raw/gadm/gadm41_KEN_2.shp"

OUTPUT_GEOJSON = f"{BASE_DIR}/data/processed/gadm_kenya_admin2_cholera.geojson"

# %% [markdown]
# ### **Loading Predictions Table**

# %%
pred = pd.read_csv(PRED_PATH)
pred.head()
# Out:
#         GID_2 location_clean  year  month  cholera_incidence  \
# 0  KEN.10.2_1   kajiado east  2023      3       8.268743e+05
# 1  KEN.10.2_1   kajiado east  2023      4       6.201557e+05
# 2  KEN.10.2_1   kajiado east  2023      5       1.033593e+06
# 3  KEN.10.2_1   kajiado east  2023      6       2.067186e+05
# 4  KEN.10.3_1  kajiado north  2023      1       1.804967e+04
#
#    predicted_incidence
# 0         6.871783e+06
# 1         2.230127e+07
# 2         3.882410e+06
# 3         2.991216e+05
# 4         8.314819e+05

# %%
assert pred["GID_2"].isna().sum() == 0
assert pred["predicted_incidence"].isna().sum() == 0

# %% [markdown]
# ### **Loading GADM Admin-2 Geometry**

# %%
gadm = gpd.read_file(GADM_PATH)

gadm = gadm[["GID_2","NAME_2","geometry"]]
gadm.head()
# Out:
#        GID_2           NAME_2  \
# 0  KEN.1.1_1              805
# 1  KEN.1.2_1  Baringo Central
# 2  KEN.1.3_1    Baringo North
# 3  KEN.1.4_1    Baringo South
# 4  KEN.1.5_1    Eldama Ravine
#
#                                             geometry
# 0  POLYGON ((35.87727 -0.02973, 35.87699 -0.02947...
# 1  POLYGON ((35.7977 0.3395, 35.79765 0.33912, 35...
# 2  POLYGON ((35.81346 0.60276, 35.81318 0.602, 35...
# 3  POLYGON ((36.22934 0.42293, 36.22926 0.42207, ...
# 4  POLYGON ((35.82341 0.0244, 35.8237 0.02429, 35...

# %% [markdown]
# ### **CRS check**

# %%
gadm = gadm.to_crs(epsg=4326)

# %% [markdown]
# ## **Merging Geometry with Predictions**

# %%
gdf = gadm.merge(
    pred,
    on="GID_2",
    how="inner"
    )

# %%
print("Rows in predictions: ",len(pred))
print("Rows after merge: ",len(gdf))
# Out:
# Rows in predictions:  235
# Rows after merge:  235

# %% [markdown]
# ## **Cleaning Columns for Streamlit**

# %%
gdf=gdf.rename(columns={
    "NAME_2":"district",
    "cholera_incidence":"observed_incidence"
})

# %%
gdf=gdf[
    [
        "GID_2",
        "district",
        "year",
        "month",
        "observed_incidence",
        "predicted_incidence",
        "geometry"
    ]
]

# %% [markdown]
# ## **Exporting GeoJSON**

# %%
gdf.to_file(OUTPUT_GEOJSON, driver="GeoJSON")

print("GeoJSON saved to:")
print(OUTPUT_GEOJSON)
# Out:
# GeoJSON saved to:
# /content/drive/MyDrive/Colab Notebooks/Kenya_Cholera_Climate_Risk_Model/data/processed/gadm_kenya_admin2_cholera.geojson
